# %%
import pandas as pd
import numpy as np

matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %%
#investigating missing data
# 2 seasons * 20 squads * 38 matches

38 * 20 * 2

# we have only 1389 rows means were missing data
# Out:
# 1520

# %%
matches['team'].value_counts()  ## Missing Liverpool 2021-2022
# Out:
# Southampton                 72
# Newcastle United            72
# Manchester United           72
# West Ham United             72
# Brighton and Hove Albion    72
# Leeds United                71
# Crystal Palace              71
# Burnley                     71
# Manchester City             71
# Arsenal                     71
# Tottenham Hotspur           71
# Wolverhampton Wanderers     71
# Aston Villa                 70
# Everton                     70
# Leicester City              70
# Chelsea                     70
# Liverpool                   38
# Sheffield United            38
# West Bromwich Albion        38
# Fulham                      38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches[matches['team'] == 'Liverpool'].sort_values('date')
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
matches['round'].value_counts()
# Out:
# Matchweek 16    39
# Matchweek 29    39
# Matchweek 4     39
# Matchweek 23    39
# Matchweek 17    39
# Matchweek 26    39
# Matchweek 9     39
# Matchweek 34    39
# Matchweek 24    39
# Matchweek 1     39
# Matchweek 8     39
# Matchweek 7     39
# Matchweek 10    39
# Matchweek 25    39
# Matchweek 13    39
# Matchweek 14    39
# Matchweek 20    39
# Matchweek 19    39
# Matchweek 2     39
# Matchweek 28    39
# Matchweek 11    39
# Matchweek 12    39
# Matchweek 15    39
# Matchweek 31    39
# Matchweek 5     39
# Matchweek 6     39
# Matchweek 32    39
# Matchweek 3     39
# Matchweek 30    37
# Matchweek 21    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 38    20
# Matchweek 36    20
# Matchweek 37    20
# Name: round, dtype: int64

# %%
matches.dtypes  #ML algo only works with float64 & int64 not objects
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches['date']= pd.to_datetime(matches['date'])
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# ...

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
#creating predictors for mL
#convert venue column into categorical so its a number value

matches['venue_code']= matches['venue'].astype('category').cat.codes  

#we created a col called venue code for the categorical value

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# ...

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# ...

# %%
#converting the time in time column (prev format is h:m but were changing to just hour)
#the code takes time column only keeps hour and leaves blank for minute

matches['hour'] = matches['time'].str.replace(':.+', '', regex=True).astype('int')

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   sot  dist   fk   pk pkatt season  \
# ...

# %%
matches['day_code']= matches['date'].dt.dayofweek

# %%
#were creating a target col that only give 1 to wins and 0 for both loss and draw just for simplicity

matches['target'] = (matches['result'] == 'W').astype('int')

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# random forest is a series of decision tress
# n_estimators is number or branches individidual decision tress with slighlty different parameters
#the higher n_estimators is longer itll run and more accurate itll be
# min_sample_split is number of samples before we split the node of the tree 
#the higher min_sample_split is the lower the accuracy  

rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2022-01-01']

# %%
test = matches[matches['date'] > '2022-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
# rf fit takes sample from predictors and predicts outcome 1 for win or 0 for loss/draw

rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
# below calculates what prediction of the time your prediction was accurate

from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)

# %%
# we can see 61% of the time our accuracy was correct

acc
# Out:
# 0.6123188405797102

# %%
# which situation our accuracy were high or low

combined = pd.DataFrame(dict(actual = test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])

#from table we can see we were right 141 times and wrong 76 times for draw/loss
# we were right 28 times for win and wrong 31 times for win
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
from sklearn.metrics import precision_score

# %%
# win accuracy score - 47%

precision_score(test['target'], preds)
# Out:
# 0.4745762711864407

# %%
# team grouping

grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Manchester City').sort_values('date')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2020-09-21  20:15  Premier League   Matchweek 2  Mon  Away      W  3.0
# 2  2020-09-27  16:30  Premier League   Matchweek 3  Sun  Home      L  2.0
# 4  2020-10-03  17:30  Premier League   Matchweek 4  Sat  Away      D  1.0
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group['date'] = pd.to_datetime(group['date'], errors = 'coerce')
    group = group.sort_values('date')
    group = group.set_index('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.reset_index()
    group = group.dropna(subset=new_cols)   #removes rows with missing values
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols   #new columns with rolling averages
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 2  2020-10-03  17:30  Premier League   Matchweek 4  Sat  Away      D  1.0
# 3  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 4  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 5  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 6  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 66 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 67 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 68 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 69 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 70 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 2  2020-09-28  20:00  Premier League   Matchweek 3
#                         3  2020-10-04  14:00  Premier League   Matchweek 4
#                         4  2020-10-17  17:30  Premier League   Matchweek 5
#                         5  2020-10-25  19:15  Premier League   Matchweek 6
#                         6  2020-11-01  16:30  Premier League   Matchweek 7
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 66 2022-03-13  14:00  Premier League  Matchweek 29
#                         67 2022-03-18  20:00  Premier League  Matchweek 30
#                         68 2022-04-02  15:00  Premier League  Matchweek 31
#                         69 2022-04-08  20:00  Premier League  Matchweek 32
#                         70 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
# dropping the team level on the left side

matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 2  2020-09-28  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 3  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 4  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 5  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 6  2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 66 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 67 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 68 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 69 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 70 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
#unique values for indexes so we get unqiue values

matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-09-28  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 1    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 2    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 3    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 4    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1335 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1336 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1337 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1338 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1339 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
#Retraining our ML

def make_predictions(data, predictors):
    train = data[data['date'] < '2022-01-01']
    test = data[data['date'] > '2022-01-01']
    rf.fit(train[predictors], train['target'])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], predicted = preds), index=test.index)
    precision = precision_score(test['target'], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision   #you can see our predictions went up from 47%
# Out:
# 0.6941176470588235

# %%
combined
# Out:
#       actual  predicted
# 56         0          1
# 57         1          0
# 58         1          1
# 59         1          1
# 60         1          1
# ...      ...        ...
# 1335       1          1
# 1336       0          1
# 1337       1          0
# 1338       0          0
# 1339       0          0
#
# [276 rows x 2 columns]

# %%
#adding the other columns by merging them based on index

combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted     date_x                   team_x     opponent_x  \
# 56         0          1 2022-01-23                  Arsenal        Burnley
# 57         1          0 2022-02-10                  Arsenal         Wolves
# 58         1          1 2022-02-19                  Arsenal      Brentford
# 59         1          1 2022-02-24                  Arsenal         Wolves
# 60         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1335       1          1 2022-03-13  Wolverhampton Wanderers        Everton
# 1336       0          1 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1337       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1338       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1339       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %%
#Combining Home & Away predictions

# %%
#we need to make sure the team names are the same for both team and opponent columns as theyre different for ex: wolves & wolverhampton wanderes

class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton", 
    "Manchester United": "Manchester Utd", 
    "Newcastle United": "Newcastle Utd", 
    "Tottenham Hotspur": "Tottenham", 
    "West Ham United": "West Ham", 
    "Wolverhampton Wanderers": "Wolves"

} 

mapping = MissingDict(**map_values)

# %%
mapping['West Ham United']
# Out:
# 'West Ham'

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
#so this would show lets say ex: if model predicted team A would win and team B would lose what actually heppened?

merged[(merged['predicted_x']==1) & (merged['predicted_y']== 0)]['actual_x'].value_counts()
# Out:
# 1    55
# 0    19
# Name: actual_x, dtype: int64

# %%
55/74  #accuracy
# Out:
# 0.7432432432432432
